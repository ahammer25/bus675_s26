# %% [markdown]
# # Lab 1: Building a Text-Based Adventure RPG 🎮⚔️
#
# **"We came, we saw, we kicked its ass!"** — Peter Venkman, *Ghostbusters (1984)*

# %% [markdown]
# ## Welcome, Adventurer!
#
# In this lab, you'll build your very own text-based adventure RPG using the object-oriented programming skills you learned in Lecture 4. Text adventures were *huge* in the 1980s—games like *Zork* and *Colossal Cave Adventure* captured imaginations before fancy graphics existed. Now it's your turn to create one!
#
# **The Goal**: Build a working text-based adventure game with:
# - A character system (player and enemies)
# - Multiple connected locations to explore
# - A dice-based combat system
# - A win condition (defeat a boss, retrieve an artifact, escape, etc.)
#
# **Time Budget**:
# - In-class Session 1: ~1 hour 15 minutes (Planning + Core Classes)
# - In-class Session 2: ~1 hour 15 minutes (Combat + Game Loop)
# - Out-of-class: >=1 hour 15 minutes (Polish + Creativity + README)
#
# **Important**: The point of this lab isn't just to make a game—it's to get comfortable managing interconnected OOP code, which is *exactly* what you'll encounter on real ML/analytics teams. Build iteratively, test often, and have fun!
#
# ### 🛠️ A Note About the Starter Code
#
# The code provided throughout this lab is meant to **guide** you, not **constrain** you. Think of it as scaffolding—a suggested structure to get you started. You should feel completely free to:
#
# - **Modify** any code we provide to fit your vision
# - **Add** new methods, attributes, or entire classes
# - **Reorganize** things if a different structure makes more sense for your game
# - **Ignore** suggestions that don't work for your theme
#
# This is YOUR game. If you want your combat system to work differently, your locations to have different attributes, or your classes organized another way—go for it! The requirements are about *what* your game should do (have characters, locations, combat, etc.), not *how* you implement it.
#
# ### A Note about Deliverables
#
# There's a checklist of deliverables at the end of this notebook. You can do your work in this notebook as it guides you along, but ultimately you will copy your code to `labs/LAB01_submission/`. In this folder, you will submit:
# 1. GAME CODE: `game.py` (and other .py files if you prefer) containing your classes and game logic
# 2. DESIGN DOCUMENT: `design.md` file in your submission folder where you write/update your game design notes as you work through the lab
# 3. README: `readme.md` file in your submission folder, explaining how to play your game
# 4. REFLECTION: `reflection.md` file in your submission folder, discussing your OOP design decisions
#
# If you prefer, the starter code from this notebook is already copied into `game.py` and stubs for the markdown documents. You can choose to edit files directly in the submission folder as you work through the lab. Just make sure to work iteratively, test early, test often, following the testing suggestions in this notebook. Keep your design notes and README/reflection in the appropriate markdown files in the submission folder. Or work here and copy files over at the end—whatever workflow you prefer!

# %% [markdown]
# ---
#
# ## Choose Your Adventure Theme! 🎬
#
# The best part of building your own game is making it *yours*. Here are some theme ideas to spark your imagination:
#
# ### Classic Fantasy 🧙‍♂️
# You're a brave hero who must descend into the Dungeon of Doom to recover the Gem of Power from the evil Dragon Lord.
#
# ### 80s Action Movie Mashup 💥
# You're an action hero trapped in Nakatomi Plaza (or a jungle, or a post-apocalyptic wasteland). Fight your way through henchmen to confront the main villain. "Get to da choppa!"
#
# ### Haunted House Mystery 👻
# You're a paranormal investigator exploring a haunted mansion. Defeat ghosts, find cursed artifacts, and escape before dawn. "Who you gonna call?"
#
# ### Sci-Fi Space Station 🚀
# Your space station has been overrun by aliens/robots/mutants. Navigate through different sectors, find weapons, and reach the escape pod—or activate the self-destruct!
#
# ### Time Travel Adventure ⏰
# You've accidentally traveled through time! Navigate different eras, collect items you need to fix your time machine, and get back to 1985 before you cease to exist!
#
# ### Your Own Idea 🎨
# Underwater kingdom? Zombie apocalypse? A heist gone wrong? Corporate office survival horror? Go wild!
#
# ---

# %% [markdown]
# ## Part 1: Planning Your Game
#
# Before writing any code, sketch out your game design. Trust me, 15 minutes of planning saves hours of confused debugging.
#
# ### 1.1 Suggested Questions to get Started:
#
# Grab a piece of paper (or use the markdown cell below) and use the following to guide your design (though you don't have to answer these questions specifically):
#
# 1. **What's your theme/setting?**
# 2. **What's the player's goal?** (Defeat a boss? Escape? Find an artifact?)
# 3. **What are your 4-6 locations?** Sketch a simple map showing how they connect.
# 4. **What enemies will the player face?** (2-4 types is plenty)
# 5. **How does the player win?** What's the victory condition?
# 6. **How does the player lose?** (Health reaches 0? Time runs out?)
#
# ### Your Game Design Notes (update this as you work through the lab):
#
# > **Submission note**: Feel free to use this cell as a workspace for your design notes and then copy the final version to `labs/LAB01_submission/design.md`. Or you can directly edit that file as you go!
#
# *Double-click this cell and write your plans here!*

# %% [markdown]
# Amelia Planning Cell!!
#
# 1) You play as a duck named Sir Quacks-a-Lot. Sir Quacks-a-Lot is a family man who has a wife named Quackie O and 3 beautiful ducklings named Pip, Mip, and Sip. Sir Quacks-a-Lot was in charge of watching the kids for a day while Quackie O gets a much neeeded vacation. Unfortunatley while Sir Quacks-a-Lot had his back turned for a second all of the little ducklings disapeared. Now Sir Quacks-a-Lot needs to venture through central park so find his three missing ducklings before Quackie O gets back and he gets in huge trouble.
#
# 2) The goal is to serch central park and try and find Pip, Mip, and Sip before the time runs out (aka Quackie O gets home and realizes the ducklings are missing).
#
# 3) The locations will be all in central park as a whole but the specific:
#     * the Quacks-a-Lot home
#     * a pond
#     * a hot dog stand
#     * a playground
#     * Belvedere Castle
#     * Cherry Hill
#     * Strawberry Fields
#
# 4) Enimies:
#     * little kids
#     * raccons
#     * dogs
#     * snapping turtle?
#     * Quackie O if you dont find the ducklings in time
#
# 5) the player wins if you can find the ducklings before Quackie O gets home
#
# 6) the player loses if the timer runs out before you find the ducklings

# %% [markdown]
# ### 1.2 Sketch Your Class Hierarchy
#
# Think about what classes you'll need. This is much easier to brainstrom with paper/pencil or on the whiteboard. You can use the below style to "officially document" your class hierarchy in your design documentation, when its finalized. Here's a suggested structure, but feel free to modify:
#
# ```
# Character (base class)
# ├── Player
#     └── Sir Quacks-a-Lot
# ├── Duck Family
#     ├── Quackie O
#     ├── Pip
#     ├── Mip
#     └── Sip
# ├── Friends
#     ├── Old Man
#     ├── Baby
#     └── Hot Dog Vendor
# └── Enemy
#     ├── raccons (weak enemy)
#     ├── little kids (medium enemy)
#     └── dogs (final challenge)
#
# Location
#
#
# Item (optional)
# ├── Weapon
# ├── Potion
# └── Key
#
# Game (manages game state and loop)
# ```
#
# **Minimum requirement**: At least 5 classes with proper inheritance.

# %% [markdown]
# ---
#
# ## Part 2: Building the Character System
#
# Let's start with the foundation: characters! Every RPG needs a way to represent the player and enemies.
#
# ### 2.1 The Character Base Class
#
# Create a `Character` class with:
# - **Attributes**: `name`, `health`, `max_health`, `strength`, `defense`
# - **Methods**:
#   - `__init__()`: Initialize the character
#   - `is_alive()`: Returns True if health > 0
#   - `take_damage(amount)`: Reduce health (but don't go below 0)
#   - `attack(target)`: Roll dice, calculate damage, apply to target
#   - `__str__()`: Return a nice string representation
#
# ### The D20 Combat System
#
# We'll use a simple dice-based combat system:
#
# 1. **Attack Roll**: Roll a d20 (1-20). Add attacker's strength.
# 2. **Defense Check**: If attack roll > target's defense, hit! Otherwise, miss.
# 3. **Damage**: On a hit, deal `strength` damage (or roll dice for variable damage)
#
# ```python
# import random
#
# def roll_d20():
#     return random.randint(1, 20)
#
# def roll_dice(num_dice, sides):
#     """Roll multiple dice and return the total. E.g., roll_dice(2, 6) for 2d6."""
#     return sum(random.randint(1, sides) for _ in range(num_dice))
# ```

# %%
# YOUR CODE: Build your Character base class here
import random

def roll_d20():
    """Roll a 20-sided die."""
    return random.randint(1, 20)

def roll_dice(num_dice, sides):
    """Roll multiple dice and return the total. E.g., roll_dice(2, 6) for 2d6."""
    return sum(random.randint(1, sides) for _ in range(num_dice))


class Character:
    """Base class for all characters in the game."""
    
    def __init__(self, name, health, strength, defense):
        # Initialize attributes
        self.name = name
        self.max_health = int(health)
        self.health = int(health)
        self.strength = int(strength)
        self.defense = int(defense)
    
    def is_alive(self):
        # Return True if health > 0
        return self.health > 0
    
    def take_damage(self, amount):
        amount = max(0, int(amount))
        self.health = max(0, self.health - amount)
        print(f"💥 Oh no! {self.name} takes {amount} damage! (HP: {self.health}/{self.max_health})")
    
    
    def attack(self, target):
        roll = roll_d20()
        attack_total = roll + self.strength
        
        print(f"🎲 {self.name} attacks! Roll: {roll} + STR({self.strength}) = {attack_total}")
        if attack_total > target.defense:
            damage = self.strength
            print(f"✅ Hit! {self.name} deals {damage} damage to {target.name}.")
            target.take_damage(damage)
        else:
            print(f"❌ Miss! {target.name}'s DEF({target.defense}) blocks the attack.")
    
    def __str__(self):
        return f"{self.name} (HP: {self.health}/{self.max_health})"

# %% [markdown]
# ### 2.2 Player and Enemy Subclasses
#
# Now create subclasses that inherit from `Character`:
#
# **Player class** might have:
# - An `inventory` list
# - Methods: `pick_up(item)`, `use_item(item_name)`, `show_inventory()`
# - A special ability (heal, power attack, etc.)
#
# **Enemy class** might have:
# - An `xp_value` (experience points when defeated)
# - A `loot` attribute (what they drop)
# - Override `attack()` with different behavior
#
# **Specific enemy types** (Minion, Elite, Boss) can have:
# - Different base stats
# - Unique abilities
# - Different attack messages (make it fun!)

# %%
# YOUR CODE: Build Player and Enemy classes here

class Player(Character):
    """The player character."""
    
    def __init__(self, name):
        super().__init__(name=name, health=40, strength=6, defense=12)
        self.inventory = []
    
    def pick_up(self, item):
        self.inventory.append(item)
        print(f"{self.name} picked up: {item}")
    
    def show_inventory(self):
        if not self.inventory:
            print("Inventory is empty. )")
            return
        print("Inventory:")
        for i, item in enumerate(self.inventory, start=1):
            print(f"  {i}. {item}")
    
    def heal(self, amount):
        amount = int(amount)
        old_hp = self.health
        self.health = min(self.max_health, self.health + amount)
        gained = self.health - old_hp
        print(f"💚 {self.name} heals {gained} HP! (HP: {self.health}/{self.max_health})")

    def boost_strength(self, amount):
        amount = int(amount)
        self.strength += amount
        print(f"💪 {self.name}'s STR increased by {amount}! (STR: {self.strength})")

    def boost_defense(self, amount):
        amount = int(amount)
        self.defense += amount
        print(f"🛡️ {self.name}'s DEF increased by {amount}! (DEF: {self.defense})")

class Enemy(Character):
    """Base class for enemies."""
    
    def __init__(self, name, health, strength, defense):
        super().__init__(name=name, health=health, strength=strength, defense=defense)

# TODO: Create specific enemy types (Minion, Elite, Boss)
# Example:
# class Goblin(Enemy):
#     def __init__(self):
#         super().__init__("Goblin", health=15, strength=3, defense=8, xp_value=5)
class LittleKid(Enemy):
    def __init__(self):
        super().__init__(name="Overexcited Kid", health=10, strength=2, defense=9)
    
    def attack(self, target):
        print("🧃 The kid shrieks: 'DUCKYYYYY!'")
        print("👟 Tiny sneakers charge toward you at full speed!")
        super().attack(target)
        
class Raccoon(Enemy):
    def __init__(self):
        super().__init__(name="Raccoon", health=16, strength=3, defense=11)
    
    def attack(self, target):
        print("🦝 The raccoon hisses and lunges from the shadows!")
        print("🗑️ It swings a mysterious trash item at you!")
        super().attack(target)

class OffLeashDog(Enemy):
    def __init__(self):
        super().__init__(name="Off Leash Dog", health=22, strength=4, defense=12)
    
    def attack(self, target):
        print("🐶 The dog barks aggressively!")
        print("💨 It sprints at you with unstoppable zoomies!")
        super().attack(target)

class SnappingTurtle(Enemy):
    def __init__(self):
        super().__init__(name="Snapping Turtle", health=28, strength=5, defense=13)
    
    def attack(self, target):
        print("🐢 The turtle slowly opens its jaws...")
        print("⚠️ CHOMP!!!")
        super().attack(target)

# %%
#Amelia Test Code 
p = Player("Sir Quacks-a-Lot")
e = Raccoon()
p.attack(e)
print(e)
# Out:
# 🎲 Sir Quacks-a-Lot attacks! Roll: 1 + STR(6) = 7
# ❌ Miss! Raccoon's DEF(11) blocks the attack.
# Raccoon (HP: 16/16)

# %% [markdown]
# ### 2.3 Test Your Characters!
#
# Before moving on, make sure your character system works. Create a player and an enemy, then have them fight!

# %%
# TEST: Create characters and test combat

# Create characters
player = Player("Sir Quacks-a-Lot")
enemy = OffLeashDog()  

print("=== Starting Stats ===")
print(player)
print(enemy)

print("\n=== Combat Test ===")

round_num = 1
while player.is_alive() and enemy.is_alive() and round_num <= 10:
    print(f"\n--- Round {round_num} ---")
    
    # Player attacks first
    player.attack(enemy)
    if not enemy.is_alive():
        print(f"\n🏆 {enemy.name} is defeated!")
        break
    
    # Enemy attacks back
    enemy.attack(player)
    if not player.is_alive():
        print(f"\n💀 {player.name} has been defeated!")
        break
    
    round_num += 1

print("\n=== Final Stats ===")
print(player)
print(enemy)
# Out:
# === Starting Stats ===
# Sir Quacks-a-Lot (HP: 40/40)
# Off Leash Dog (HP: 22/22)
#
# === Combat Test ===
#
# --- Round 1 ---
# 🎲 Sir Quacks-a-Lot attacks! Roll: 11 + STR(6) = 17
# ✅ Hit! Sir Quacks-a-Lot deals 6 damage to Off Leash Dog.
# 💥 Oh no! Off Leash Dog takes 6 damage! (HP: 16/22)
# 🐶 The dog barks aggressively!
# 💨 It sprints at you with unstoppable zoomies!
# 🎲 Off Leash Dog attacks! Roll: 20 + STR(4) = 24
# ✅ Hit! Off Leash Dog deals 4 damage to Sir Quacks-a-Lot.
# 💥 Oh no! Sir Quacks-a-Lot takes 4 damage! (HP: 36/40)
#
# --- Round 2 ---
# 🎲 Sir Quacks-a-Lot attacks! Roll: 14 + STR(6) = 20
# ✅ Hit! Sir Quacks-a-Lot deals 6 damage to Off Leash Dog.
# 💥 Oh no! Off Leash Dog takes 6 damage! (HP: 10/22)
# 🐶 The dog barks aggressively!
# 💨 It sprints at you with unstoppable zoomies!
# 🎲 Off Leash Dog attacks! Roll: 1 + STR(4) = 5
# ❌ Miss! Sir Quacks-a-Lot's DEF(12) blocks the attack.
#
# --- Round 3 ---
# 🎲 Sir Quacks-a-Lot attacks! Roll: 9 + STR(6) = 15
# ✅ Hit! Sir Quacks-a-Lot deals 6 damage to Off Leash Dog.
# 💥 Oh no! Off Leash Dog takes 6 damage! (HP: 4/22)
# 🐶 The dog barks aggressively!
# 💨 It sprints at you with unstoppable zoomies!
# 🎲 Off Leash Dog attacks! Roll: 6 + STR(4) = 10
# ❌ Miss! Sir Quacks-a-Lot's DEF(12) blocks the attack.
#
# --- Round 4 ---
# 🎲 Sir Quacks-a-Lot attacks! Roll: 16 + STR(6) = 22
# ✅ Hit! Sir Quacks-a-Lot deals 6 damage to Off Leash Dog.
# 💥 Oh no! Off Leash Dog takes 6 damage! (HP: 0/22)
#
# 🏆 Off Leash Dog is defeated!
#
# === Final Stats ===
# Sir Quacks-a-Lot (HP: 36/40)
# Off Leash Dog (HP: 0/22)

# %% [markdown]
# ---
#
# ## Part 3: Building the World
#
# Now let's create locations for your adventure!
#
# ### 3.1 The Location Class
#
# Each location needs:
# - **Attributes**: `name`, `description`, `connections` (dict mapping directions to other locations), `enemies` (list), `items` (list)
# - **Methods**:
#   - `describe()`: Print the location description and what's here
#   - `get_exits()`: Return available directions
#   - `add_connection(direction, location)`: Connect to another location
#
# **Pro tip**: Store connections as a dictionary: `{"north": cave, "south": village}`

# %%
# YOUR CODE: Build the Location class

class Location:
    """A location in the game world."""
    
    def __init__(self, name, description):
        self.name = name
        self.description = description
        self.connections = {}  # {"north": Location, "south": Location, etc.}
        self.enemies = []      # List of enemies in this location
        self.items = []        # List of items in this location
    
    def describe(self):
        """Print a full description of the location."""
        print(f"\n{'='*50}")
        print(f"📍 {self.name}")
        print(f"{'='*50}")
        print(self.description)
        
        if self.items:
            print("\n✨ You see:")
            for item in self.items:
                print(f"  - {item}")
        
        alive_enemies = [e for e in self.enemies if e.is_alive()]
        if alive_enemies:
            print("\n👀 Threats nearby:")
            for e in alive_enemies:
                print(f"  - {e.name} (HP {e.health}/{e.max_health}, DEF {e.defense})")
        
        exits = self.get_exits()
        if exits:
            print("\n🚪 Exits:", ", ".join(exits))
            
    def get_exits(self):
        """Return a list of available directions."""
        return list(self.connections.keys())
    
    def add_connection(self, direction, location):
        """Connect this location to another."""
        self.connections[direction] = location

# %% [markdown]
# ### 3.2 Create Your World
#
# Build your game world by creating locations and connecting them. Here's an example structure:
#
# ```
#                     [Tower Top]
#                          |
#                        north
#                          |
# [Forest] -- east --> [Castle] -- north --> [Dungeon]
#                          |
#                        south
#                          |
#                     [Village]
# ```

# %%
# YOUR CODE: Create your game world

def create_world():
    # --- Locations ---
    home = Location(
        "Quacks-a-Lot Home",
        "Your cozy home. One second you blinked and your ducklings vanished. "
        "Find Pip, Mip, and Sip before Quackie O gets home!"
    )

    pond = Location(
        "The Pond",
        "The water is calm… too calm. A turtle is posted up like security."
    )

    hotdog = Location(
        "Hot Dog Stand",
        "It smells incredible. Pigeons are lurking. A dog is watching you like you owe it lunch."
    )

    playground = Location(
        "Playground",
        "Absolute chaos. Tiny humans sprint in random directions. One kid points and yells 'DUCK!!!'"
    )

    castle = Location(
        "Belvedere Castle",
        "A mini castle with haunting energy. Echoes bounce off the stone walls."
    )

    cherry_hill = Location(
        "Cherry Hill",
        "A peaceful hill with benches and trees. You swear you hear faint peeping nearby."
    )

    strawberry_fields = Location(
        "Strawberry Fields",
        "Quiet and calm. A place where you can think… but don’t think too long."
    )

    # --- Connections (simple, readable map) ---
    home.add_connection("north", playground)
    playground.add_connection("south", home)

    playground.add_connection("east", hotdog)
    hotdog.add_connection("west", playground)

    playground.add_connection("north", pond)
    pond.add_connection("south", playground)

    pond.add_connection("east", castle)
    castle.add_connection("west", pond)

    pond.add_connection("west", cherry_hill)
    cherry_hill.add_connection("east", pond)

    cherry_hill.add_connection("north", strawberry_fields)
    strawberry_fields.add_connection("south", cherry_hill)

    # --- Enemies (use your enemy classes) ---
    # If your class names differ, just swap these
    playground.enemies.append(LittleKid())
    cherry_hill.enemies.append(Raccoon())
    hotdog.enemies.append(OffLeashDog())
    pond.enemies.append(SnappingTurtle())

    # --- Ducklings as items to pick up ---
    # Treat them as items so your inventory can track them
    castle.items.append("Duckling: Pip")
    strawberry_fields.items.append("Duckling: Mip")
    hotdog.items.append("Duckling: Sip")

    #fun/utility items
    home.items.append("Bread Crumbs")
    playground.items.append("Band-Aid")
    pond.items.append("Shiny Pebble")
    hotdog.items.append("Protein Hot Dog")         # +2 STR
    pond.items.append("Pond Water Espresso")       # +12 HP
    cherry_hill.items.append("Old Man")

    # Starting location
    return home

# Test your world
# starting_location = create_world()
# starting_location.describe()

# %%
#Amelia Test Code 
start = create_world()
start.describe()

print("\nTesting moving north from start...")
next_loc = start.connections["north"]
next_loc.describe()
# Out:
# ==================================================
# 📍 Quacks-a-Lot Home
# ==================================================
# Your cozy home. One second you blinked and your ducklings vanished. Find Pip, Mip, and Sip before Quackie O gets home!
#
# ✨ You see:
#   - Bread Crumbs
#
# 🚪 Exits: north
#
# Testing moving north from start...
#
# ==================================================
# 📍 Playground
# ==================================================
# Absolute chaos. Tiny humans sprint in random directions. One kid points and yells 'DUCK!!!'
#
# ✨ You see:
#   - Band-Aid
#
# 👀 Threats nearby:
#   - Overexcited Kid (HP 10/10, DEF 9)
#
# 🚪 Exits: south, east, north

# %% [markdown]
# ---
#
# ## Part 4: The Combat System
#
# Time to make battles exciting! We'll implement a turn-based combat system using a simple state machine.
#
# ### 4.1 Combat States
#
# Combat flows through states. For example, here is one simple way to do it:
# 1. **PLAYER_TURN**: Player chooses an action
# 2. **ENEMY_TURN**: Enemy attacks
# 3. **COMBAT_END**: Someone won (or ran away)
#
# ```
# ┌─────────────────────────────────────────────────────────┐
# │                                                         │
# │  [PLAYER_TURN] ─── attack ──→ [ENEMY_TURN]              │
# │       │                            │                    │
# │       │                            │                    │
# │       │←─────── (enemy alive) ─────┘                    │
# │       │                            │                    │
# │       │                            ▼                    │
# │       │                      (enemy dead?)              │
# │       │                            │                    │
# │       └── run away ─────→ [COMBAT_END] ←────────────────┘
# │                                                         │
# └─────────────────────────────────────────────────────────┘
# ```

# %%
# YOUR CODE: Implement the combat system

class Combat:
    """Manages turn-based combat between player and enemy."""
    
    # Combat states
    PLAYER_TURN = "player_turn"
    ENEMY_TURN = "enemy_turn"
    COMBAT_END = "combat_end"
    
    def __init__(self, player, enemy):
        self.player = player
        self.enemy = enemy
        self.state = Combat.PLAYER_TURN
        self.combat_log = []
    
    def start(self):
        """Begin combat and run until someone wins/loses/flees."""
        print(f"\n⚔️ COMBAT BEGINS! ⚔️")
        print(f"{self.player.name} vs {self.enemy.name}!")
        
        while self.state != Combat.COMBAT_END:
            if self.state == Combat.PLAYER_TURN:
                self.player_turn()
            elif self.state == Combat.ENEMY_TURN:
                self.enemy_turn()
        
        return self.get_result()
    
    def player_turn(self):
        """Handle player's turn in combat."""
        print(f"\n{self.player} | {self.enemy}")
        print("What do you do? (attack / run)")
        
        action = input("> ").lower().strip()
        
        if action == "attack":
            self.player.attack(self.enemy)
            if not self.enemy.is_alive():
                print(f"\n🎉 {self.enemy.name} has been defeated!")
                self.state = Combat.COMBAT_END
            else:
                self.state = Combat.ENEMY_TURN
        
        elif action == "run":
            # 50% chance to escape
            if random.random() < 0.5:
                print("You successfully fled!")
                self.state = Combat.COMBAT_END
            else:
                print("Couldn't escape!")
                self.state = Combat.ENEMY_TURN
        
        else:
            print("Invalid action. Try 'attack' or 'run'.")
    
    def enemy_turn(self):
        """Handle enemy's turn in combat."""
        print(f"\n{self.enemy.name}'s turn...")
        self.enemy.attack(self.player)
        
        if not self.player.is_alive():
            print(f"\n💀 {self.player.name} has fallen!")
            self.state = Combat.COMBAT_END
        else:
            self.state = Combat.PLAYER_TURN
    
    def get_result(self):
        """Return the combat result: 'victory', 'defeat', or 'fled'."""
        if not self.enemy.is_alive():
            return "victory"
        elif not self.player.is_alive():
            return "defeat"
        else:
            return "fled"

# %% [markdown]
# ### 4.2 Test Combat
#
# Make sure your combat system works before integrating it into the game!

# %%
# TEST: Run a test combat

hero = Player("Sir Quacks-a-Lot")
monster = Raccoon()   


battle = Combat(hero, monster)
result = battle.start()

print(f"\nCombat result: {result}")
# Out:
# ⚔️ COMBAT BEGINS! ⚔️
# Sir Quacks-a-Lot vs Raccoon!
#
# Sir Quacks-a-Lot (HP: 40/40) | Raccoon (HP: 16/16)
# What do you do? (attack / run)
# 🎲 Sir Quacks-a-Lot attacks! Roll: 13 + STR(6) = 19
# ✅ Hit! Sir Quacks-a-Lot deals 6 damage to Raccoon.
# 💥 Oh no! Raccoon takes 6 damage! (HP: 10/16)
#
# Raccoon's turn...
# 🦝 The raccoon hisses and lunges from the shadows!
# 🗑️ It swings a mysterious trash item at you!
# 🎲 Raccoon attacks! Roll: 20 + STR(3) = 23
# ✅ Hit! Raccoon deals 3 damage to Sir Quacks-a-Lot.
# 💥 Oh no! Sir Quacks-a-Lot takes 3 damage! (HP: 37/40)
#
# Sir Quacks-a-Lot (HP: 37/40) | Raccoon (HP: 10/16)
# What do you do? (attack / run)
# 🎲 Sir Quacks-a-Lot attacks! Roll: 20 + STR(6) = 26
# ✅ Hit! Sir Quacks-a-Lot deals 6 damage to Raccoon.
# 💥 Oh no! Raccoon takes 6 damage! (HP: 4/16)
#
# Raccoon's turn...
# 🦝 The raccoon hisses and lunges from the shadows!
# 🗑️ It swings a mysterious trash item at you!
# 🎲 Raccoon attacks! Roll: 4 + STR(3) = 7
# ❌ Miss! Sir Quacks-a-Lot's DEF(12) blocks the attack.
#
# Sir Quacks-a-Lot (HP: 37/40) | Raccoon (HP: 4/16)
# What do you do? (attack / run)
# 🎲 Sir Quacks-a-Lot attacks! Roll: 2 + STR(6) = 8
# ❌ Miss! Raccoon's DEF(11) blocks the attack.
#
# Raccoon's turn...
# 🦝 The raccoon hisses and lunges from the shadows!
# 🗑️ It swings a mysterious trash item at you!
# 🎲 Raccoon attacks! Roll: 1 + STR(3) = 4
# ❌ Miss! Sir Quacks-a-Lot's DEF(12) blocks the attack.
#
# Sir Quacks-a-Lot (HP: 37/40) | Raccoon (HP: 4/16)
# What do you do? (attack / run)
# 🎲 Sir Quacks-a-Lot attacks! Roll: 16 + STR(6) = 22
# ✅ Hit! Sir Quacks-a-Lot deals 6 damage to Raccoon.
# 💥 Oh no! Raccoon takes 6 damage! (HP: 0/16)
#
# 🎉 Raccoon has been defeated!
#
# Combat result: victory

# %% [markdown]
# ---
#
# ## Part 5: The Main Game Loop
#
# Now let's tie it all together! The `Game` class manages the overall game state and the main loop.
#
# ### 5.1 Game States
#
# Your main game should have these states:
# - **EXPLORING**: Player is moving around, examining locations
# - **IN_COMBAT**: Player is fighting an enemy
# - **GAME_OVER**: Player died
# - **VICTORY**: Player won!
#
# ### 5.2 Available Actions
#
# When exploring, the player might:
# - Move: `go north`, `go south`, `go east`, `go west`
# - Look around: `look`
# - Fight: `fight` or `attack`
# - Inventory: `inventory` or `i`
# - Get help: `help`
# - Quit: `quit`
#
# Handle invalid input gracefully!

# %%
# YOUR CODE: Build the main Game class

class Game:
    """Main game controller."""
    
    # Game states
    EXPLORING = "exploring"
    IN_COMBAT = "in_combat"
    GAME_OVER = "game_over"
    VICTORY = "victory"
    
    def __init__(self):
        self.player = None
        self.current_location = None
        self.state = Game.EXPLORING
        self.game_running = True
        
        # Timer + win condition
        self.turns_left = 35
        self.ducklings_needed = {"Duckling: Pip", "Duckling: Mip", "Duckling: Sip"}
    
    def start(self):
        """Initialize and start the game."""
        self.show_intro()
        self.create_player()
        self.current_location = create_world()  # Your function from earlier
        self.current_location.describe()
        
        # Main game loop
        while self.game_running:
            if self.state == Game.EXPLORING:
                self.exploration_loop()
            elif self.state == Game.GAME_OVER:
                self.show_game_over()
                break
            elif self.state == Game.VICTORY:
                self.show_victory()
                break
    
    def show_intro(self):
        """Display the game introduction."""
        print("\n" + "="*60)
        print("      🦆 SIR QUACKS-A-LOT: CENTRAL PARK RESCUE 🦆")
        print("="*60)
        print("\nQuackie O is on a much-needed vacation.")
        print("You had ONE JOB: watch Pip, Mip, and Sip.")
        print("You turned around for ONE SECOND… and the ducklings vanished into Central Park.")
        print("Find all three ducklings before Quackie O gets home!")
        print("\n" + "="*60)
    
    def create_player(self):
        """Create the player character."""
        # If you want to keep the prompt, you can—but your story is best fixed to Sir Quacks-a-Lot.
        self.player = Player("Sir Quacks-a-Lot")
        print("\nYou are Sir Quacks-a-Lot. Time to find your ducklings...")
    
    def exploration_loop(self):
        """Handle player input during exploration."""
        print("\nWhat do you do? (type 'help' for commands)")
        command = input("> ").lower().strip()
        
        # Parse the command
        parts = command.split()
        if not parts:
            return
        
        action = parts[0]
        
        if action == "help":
            self.show_help()
        
        elif action == "look":
            self.current_location.describe()
        
        elif action == "go" and len(parts) > 1:
            direction = parts[1]
            self.move(direction)
        
        elif action in ["north", "south", "east", "west", "up", "down"]:
            self.move(action)
        
        elif action in ["fight", "attack"]:
            self.initiate_combat()
        
        elif action in ["inventory", "i"]:
            self.player.show_inventory()
        
        elif action == "take" and len(parts) > 1:
            item_query = " ".join(parts[1:])
            self.take_item(item_query)
        
        elif action == "quit":
            print("Thanks for playing!")
            self.game_running = False
        
        elif action == "use" and len(parts) > 1:
            item_query = " ".join(parts[1:])
            self.use_item(item_query)
        
        elif action == "talk" and len(parts) > 1:
            who = " ".join(parts[1:])
            self.talk_to(who)
        
        else:
            print("I don't understand that command. Type 'help' for options.")
    
    def move(self, direction):
        """Move the player in the specified direction."""
        if direction in self.current_location.connections:
            self.current_location = self.current_location.connections[direction]
            self.current_location.describe()

            # Auto-trigger combat if a living enemy is here
            if any(e.is_alive() for e in self.current_location.enemies):
                print("\n⚠️ An enemy is here!")
                self.initiate_combat()
                if self.state != Game.EXPLORING:
                    return

            self.end_turn()
        else:
            print(f"You can't go {direction} from here.")
    
    def take_item(self, item_query):
        """Pick up an item by partial name match."""
        for item in list(self.current_location.items):
            if item_query.lower() in item.lower():
                self.player.pick_up(item)
                self.current_location.items.remove(item)

                if item.startswith("Duckling:"):
                    print("🦆 You found one of your ducklings!!")

                self.end_turn()
                return
        print("You don't see that here.")
    
    def talk_to(self, who_query):
        """Talk to an NPC in the current location (implemented as an item token)."""
        # Look for an NPC "item" in the room
        npc = None
        for thing in self.current_location.items:
            if who_query.lower() in thing.lower():
                npc = thing
                break

        if not npc:
            print("There’s no one like that here to talk to.")
            return

        # Old Man interaction
        if npc == "Old Man":
            print("\n👴 Old Man: 'Ahh… a hardworking duck dad. How nice!'")
            print("👴 Old Man: 'Here, take some bread. You look like you need it.'")
            print("🍞 You receive: Fresh Bread")

            # Give the player a usable item
            self.player.pick_up("Fresh Bread")

            # Optional: small heal right away (feels like he “feeds” you)
            if hasattr(self.player, "heal"):
                self.player.heal(5)

            # Remove the NPC so it only happens once
            self.current_location.items.remove("Old Man")

            self.end_turn()
            return

        print("They don’t have anything to say right now.")
    
    def initiate_combat(self):
        """Start combat with an enemy in the current location."""
        living_enemies = [e for e in self.current_location.enemies if e.is_alive()]
        if not living_enemies:
            print("There's nothing to fight here.")
            return
        
        enemy = living_enemies[0]  # Fight first living enemy
        battle = Combat(self.player, enemy)
        result = battle.start()
        
        if result == "victory":
            self.current_location.enemies.remove(enemy)
            self.end_turn()
        elif result == "defeat":
            self.state = Game.GAME_OVER
        else:  # fled
            # fleeing still costs time 
            self.end_turn()
    
    def check_victory(self):
        """Return True if player has all ducklings."""
        return self.ducklings_needed.issubset(set(self.player.inventory))
    
    def use_item(self, item_query):
        """Use an item from inventory by partial name match."""
        # Find item in inventory
        chosen = None
        for item in self.player.inventory:
            if item_query.lower() in item.lower():
                chosen = item
                break

        if not chosen:
            print("You don't have that item.")
            return

        # Item effects
        effects = {
            "Band-Aid": ("heal", 6),
            "Bread Crumbs": ("strength", 1),
            "Shiny Pebble": ("defense", 1),
            "Protein Hot Dog": ("strength", 2),
            "Pond Water Espresso": ("heal", 12),
            "Fresh Bread": ("strength", 2),
        }

        if chosen not in effects:
            print(f"{chosen} doesn't seem usable right now.")
            return

        effect_type, amount = effects[chosen]

        if effect_type == "heal":
            self.player.heal(amount)
        elif effect_type == "strength":
            self.player.boost_strength(amount)
        elif effect_type == "defense":
            self.player.boost_defense(amount)

        # Remove the item after using it (consumable)
        self.player.inventory.remove(chosen)
        print(f"✅ Used: {chosen}")

        self.end_turn()
    
    def end_turn(self):
        """After meaningful actions, reduce turns and check win/lose."""
        # Win check first so grabbing the last duckling wins instantly
        if self.check_victory():
            self.state = Game.VICTORY
            return
        
        self.turns_left -= 1
        print(f"⏳ Time left until Quackie O gets home: {self.turns_left} turns")
        
        if self.turns_left <= 0:
            self.state = Game.GAME_OVER
            print("\n🚨 QUACKIE O IS HOME.")
            print("She looks around… then looks at you.")
            print("😡 'Where. Are. The. Ducklings.'")
    
    def show_help(self):
        """Display available commands."""
        print("\n📜 AVAILABLE COMMANDS:")
        print("  go [direction] - Move (north, south, east, west)")
        print("  look          - Examine your surroundings")
        print("  take [item]   - Pick up an item (try: take pip)")
        print("  fight         - Start combat if an enemy is here")
        print("  inventory     - Check your inventory")
        print("  help          - Show this help message")
        print("  quit          - Exit the game")
        print("  use [item]    - Use an item from your inventory (try: use band-aid)")
        print("  talk [person] - Talk to someone nearby (try: talk old man)")
    
    def show_game_over(self):
        """Display game over message."""
        print("\n" + "="*60)
        print("                    GAME OVER")
        print("="*60)
        print("\nQuackie O is home… and the ducklings aren’t.")
        print("You are in HUGE trouble.")
        print("\n(But you can always try again!)")
    
    def show_victory(self):
        """Display victory message."""
        print("\n" + "="*60)
        print("                    🎉 VICTORY! 🎉")
        print("="*60)
        print("\nPip, Mip, and Sip are safe and accounted for.")
        print("Quackie O returns relaxed… and proud.")
        print("🦆 Family reunited. Parenting: SUCCESS.")

# %% [markdown]
# ---
#
# ## Part 6: Running Your Game! 🎮
#
# Once you've built all the pieces, it's time to play!

# %%
# RUN YOUR GAME!

# Uncomment when ready:
game = Game()
game.start()
# Out:
# ============================================================
#       🦆 SIR QUACKS-A-LOT: CENTRAL PARK RESCUE 🦆
# ============================================================
#
# Quackie O is on a much-needed vacation.
# You had ONE JOB: watch Pip, Mip, and Sip.
# You turned around for ONE SECOND… and the ducklings vanished into Central Park.
# Find all three ducklings before Quackie O gets home!
#
# ============================================================
#
# You are Sir Quacks-a-Lot. Time to find your ducklings...
#
# ==================================================
# 📍 Quacks-a-Lot Home
# ==================================================
# Your cozy home. One second you blinked and your ducklings vanished. Find Pip, Mip, and Sip before Quackie O gets home!
#
# ✨ You see:
#   - Bread Crumbs
#
# 🚪 Exits: north
#
# What do you do? (type 'help' for commands)
#
# 📜 AVAILABLE COMMANDS:
#   go [direction] - Move (north, south, east, west)
#   look          - Examine your surroundings
#   take [item]   - Pick up an item (try: take pip)
#   fight         - Start combat if an enemy is here
#   inventory     - Check your inventory
#   help          - Show this help message
#   quit          - Exit the game
#   use [item]    - Use an item from your inventory (try: use band-aid)
#   talk [person] - Talk to someone nearby (try: talk old man)
#
# What do you do? (type 'help' for commands)
# Sir Quacks-a-Lot picked up: Bread Crumbs
# ⏳ Time left until Quackie O gets home: 24 turns
#
# What do you do? (type 'help' for commands)
#
# ==================================================
# 📍 Playground
# ==================================================
# Absolute chaos. Tiny humans sprint in random directions. One kid points and yells 'DUCK!!!'
#
# ✨ You see:
#   - Band-Aid
#
# 👀 Threats nearby:
#   - Overexcited Kid (HP 10/10, DEF 9)
#
# 🚪 Exits: south, east, north
#
# ⚠️ An enemy is here!
#
# ⚔️ COMBAT BEGINS! ⚔️
# Sir Quacks-a-Lot vs Overexcited Kid!
#
# Sir Quacks-a-Lot (HP: 40/40) | Overexcited Kid (HP: 10/10)
# What do you do? (attack / run)
# 🎲 Sir Quacks-a-Lot attacks! Roll: 7 + STR(6) = 13
# ✅ Hit! Sir Quacks-a-Lot deals 6 damage to Overexcited Kid.
# 💥 Oh no! Overexcited Kid takes 6 damage! (HP: 4/10)
#
# Overexcited Kid's turn...
# 🧃 The kid shrieks: 'DUCKYYYYY!'
# 👟 Tiny sneakers charge toward you at full speed!
# 🎲 Overexcited Kid attacks! Roll: 10 + STR(2) = 12
# ❌ Miss! Sir Quacks-a-Lot's DEF(12) blocks the attack.
#
# Sir Quacks-a-Lot (HP: 40/40) | Overexcited Kid (HP: 4/10)
# What do you do? (attack / run)
# 🎲 Sir Quacks-a-Lot attacks! Roll: 6 + STR(6) = 12
# ✅ Hit! Sir Quacks-a-Lot deals 6 damage to Overexcited Kid.
# 💥 Oh no! Overexcited Kid takes 6 damage! (HP: 0/10)
#
# 🎉 Overexcited Kid has been defeated!
# ⏳ Time left until Quackie O gets home: 23 turns
# ⏳ Time left until Quackie O gets home: 22 turns
#
# What do you do? (type 'help' for commands)
# Sir Quacks-a-Lot picked up: Band-Aid
# ⏳ Time left until Quackie O gets home: 21 turns
#
# What do you do? (type 'help' for commands)
#
# ==================================================
# 📍 Hot Dog Stand
# ==================================================
# It smells incredible. Pigeons are lurking. A dog is watching you like you owe it lunch.
#
# ✨ You see:
#   - Duckling: Sip
#
# 👀 Threats nearby:
#   - Off Leash Dog (HP 22/22, DEF 12)
#
# 🚪 Exits: west
#
# ⚠️ An enemy is here!
#
# ⚔️ COMBAT BEGINS! ⚔️
# Sir Quacks-a-Lot vs Off Leash Dog!
#
# Sir Quacks-a-Lot (HP: 40/40) | Off Leash Dog (HP: 22/22)
# What do you do? (attack / run)
# 🎲 Sir Quacks-a-Lot attacks! Roll: 2 + STR(6) = 8
# ❌ Miss! Off Leash Dog's DEF(12) blocks the attack.
#
# Off Leash Dog's turn...
# 🐶 The dog barks aggressively!
# 💨 It sprints at you with unstoppable zoomies!
# 🎲 Off Leash Dog attacks! Roll: 17 + STR(4) = 21
# ✅ Hit! Off Leash Dog deals 4 damage to Sir Quacks-a-Lot.
# 💥 Oh no! Sir Quacks-a-Lot takes 4 damage! (HP: 36/40)
#
# Sir Quacks-a-Lot (HP: 36/40) | Off Leash Dog (HP: 22/22)
# What do you do? (attack / run)
# 🎲 Sir Quacks-a-Lot attacks! Roll: 14 + STR(6) = 20
# ✅ Hit! Sir Quacks-a-Lot deals 6 damage to Off Leash Dog.
# 💥 Oh no! Off Leash Dog takes 6 damage! (HP: 16/22)
#
# Off Leash Dog's turn...
# 🐶 The dog barks aggressively!
# 💨 It sprints at you with unstoppable zoomies!
# 🎲 Off Leash Dog attacks! Roll: 3 + STR(4) = 7
# ❌ Miss! Sir Quacks-a-Lot's DEF(12) blocks the attack.
#
# Sir Quacks-a-Lot (HP: 36/40) | Off Leash Dog (HP: 16/22)
# What do you do? (attack / run)
# 🎲 Sir Quacks-a-Lot attacks! Roll: 4 + STR(6) = 10
# ❌ Miss! Off Leash Dog's DEF(12) blocks the attack.
#
# Off Leash Dog's turn...
# 🐶 The dog barks aggressively!
# 💨 It sprints at you with unstoppable zoomies!
# 🎲 Off Leash Dog attacks! Roll: 6 + STR(4) = 10
# ❌ Miss! Sir Quacks-a-Lot's DEF(12) blocks the attack.
#
# Sir Quacks-a-Lot (HP: 36/40) | Off Leash Dog (HP: 16/22)
# What do you do? (attack / run)
# 🎲 Sir Quacks-a-Lot attacks! Roll: 10 + STR(6) = 16
# ✅ Hit! Sir Quacks-a-Lot deals 6 damage to Off Leash Dog.
# 💥 Oh no! Off Leash Dog takes 6 damage! (HP: 10/22)
#
# Off Leash Dog's turn...
# 🐶 The dog barks aggressively!
# 💨 It sprints at you with unstoppable zoomies!
# 🎲 Off Leash Dog attacks! Roll: 16 + STR(4) = 20
# ✅ Hit! Off Leash Dog deals 4 damage to Sir Quacks-a-Lot.
# 💥 Oh no! Sir Quacks-a-Lot takes 4 damage! (HP: 32/40)
#
# Sir Quacks-a-Lot (HP: 32/40) | Off Leash Dog (HP: 10/22)
# What do you do? (attack / run)
# 🎲 Sir Quacks-a-Lot attacks! Roll: 9 + STR(6) = 15
# ✅ Hit! Sir Quacks-a-Lot deals 6 damage to Off Leash Dog.
# 💥 Oh no! Off Leash Dog takes 6 damage! (HP: 4/22)
#
# Off Leash Dog's turn...
# 🐶 The dog barks aggressively!
# 💨 It sprints at you with unstoppable zoomies!
# 🎲 Off Leash Dog attacks! Roll: 2 + STR(4) = 6
# ❌ Miss! Sir Quacks-a-Lot's DEF(12) blocks the attack.
#
# Sir Quacks-a-Lot (HP: 32/40) | Off Leash Dog (HP: 4/22)
# What do you do? (attack / run)
# 🎲 Sir Quacks-a-Lot attacks! Roll: 5 + STR(6) = 11
# ❌ Miss! Off Leash Dog's DEF(12) blocks the attack.
#
# Off Leash Dog's turn...
# 🐶 The dog barks aggressively!
# 💨 It sprints at you with unstoppable zoomies!
# 🎲 Off Leash Dog attacks! Roll: 6 + STR(4) = 10
# ❌ Miss! Sir Quacks-a-Lot's DEF(12) blocks the attack.
#
# Sir Quacks-a-Lot (HP: 32/40) | Off Leash Dog (HP: 4/22)
# What do you do? (attack / run)
# Invalid action. Try 'attack' or 'run'.
#
# Sir Quacks-a-Lot (HP: 32/40) | Off Leash Dog (HP: 4/22)
# What do you do? (attack / run)
# 🎲 Sir Quacks-a-Lot attacks! Roll: 19 + STR(6) = 25
# ✅ Hit! Sir Quacks-a-Lot deals 6 damage to Off Leash Dog.
# 💥 Oh no! Off Leash Dog takes 6 damage! (HP: 0/22)
#
# 🎉 Off Leash Dog has been defeated!
# ⏳ Time left until Quackie O gets home: 20 turns
# ⏳ Time left until Quackie O gets home: 19 turns
#
# What do you do? (type 'help' for commands)
# Sir Quacks-a-Lot picked up: Duckling: Sip
# 🦆 You found one of your ducklings!!
# ⏳ Time left until Quackie O gets home: 18 turns
#
# What do you do? (type 'help' for commands)
#
# ==================================================
# 📍 Playground
# ==================================================
# Absolute chaos. Tiny humans sprint in random directions. One kid points and yells 'DUCK!!!'
#
# 🚪 Exits: south, east, north
# ⏳ Time left until Quackie O gets home: 17 turns
#
# What do you do? (type 'help' for commands)
#
# ==================================================
# 📍 Hot Dog Stand
# ==================================================
# It smells incredible. Pigeons are lurking. A dog is watching you like you owe it lunch.
#
# 🚪 Exits: west
# ⏳ Time left until Quackie O gets home: 16 turns
#
# What do you do? (type 'help' for commands)
#
# ==================================================
# 📍 Playground
# ==================================================
# Absolute chaos. Tiny humans sprint in random directions. One kid points and yells 'DUCK!!!'
#
# 🚪 Exits: south, east, north
# ⏳ Time left until Quackie O gets home: 15 turns
#
# What do you do? (type 'help' for commands)
#
# ==================================================
# 📍 The Pond
# ==================================================
# The water is calm… too calm. A turtle is posted up like security.
#
# ✨ You see:
#   - Shiny Pebble
#
# 👀 Threats nearby:
#   - Snapping Turtle (HP 28/28, DEF 13)
#
# 🚪 Exits: south, east, west
#
# ⚠️ An enemy is here!
#
# ⚔️ COMBAT BEGINS! ⚔️
# Sir Quacks-a-Lot vs Snapping Turtle!
#
# Sir Quacks-a-Lot (HP: 32/40) | Snapping Turtle (HP: 28/28)
# What do you do? (attack / run)
# 🎲 Sir Quacks-a-Lot attacks! Roll: 4 + STR(6) = 10
# ❌ Miss! Snapping Turtle's DEF(13) blocks the attack.
#
# Snapping Turtle's turn...
# 🐢 The turtle slowly opens its jaws...
# ⚠️ CHOMP!!!
# 🎲 Snapping Turtle attacks! Roll: 1 + STR(5) = 6
# ❌ Miss! Sir Quacks-a-Lot's DEF(12) blocks the attack.
#
# Sir Quacks-a-Lot (HP: 32/40) | Snapping Turtle (HP: 28/28)
# What do you do? (attack / run)
# 🎲 Sir Quacks-a-Lot attacks! Roll: 4 + STR(6) = 10
# ❌ Miss! Snapping Turtle's DEF(13) blocks the attack.
#
# Snapping Turtle's turn...
# 🐢 The turtle slowly opens its jaws...
# ⚠️ CHOMP!!!
# 🎲 Snapping Turtle attacks! Roll: 2 + STR(5) = 7
# ❌ Miss! Sir Quacks-a-Lot's DEF(12) blocks the attack.
#
# Sir Quacks-a-Lot (HP: 32/40) | Snapping Turtle (HP: 28/28)
# What do you do? (attack / run)
# 🎲 Sir Quacks-a-Lot attacks! Roll: 15 + STR(6) = 21
# ✅ Hit! Sir Quacks-a-Lot deals 6 damage to Snapping Turtle.
# 💥 Oh no! Snapping Turtle takes 6 damage! (HP: 22/28)
#
# Snapping Turtle's turn...
# 🐢 The turtle slowly opens its jaws...
# ⚠️ CHOMP!!!
# 🎲 Snapping Turtle attacks! Roll: 11 + STR(5) = 16
# ✅ Hit! Snapping Turtle deals 5 damage to Sir Quacks-a-Lot.
# 💥 Oh no! Sir Quacks-a-Lot takes 5 damage! (HP: 27/40)
#
# Sir Quacks-a-Lot (HP: 27/40) | Snapping Turtle (HP: 22/28)
# What do you do? (attack / run)
# 🎲 Sir Quacks-a-Lot attacks! Roll: 20 + STR(6) = 26
# ✅ Hit! Sir Quacks-a-Lot deals 6 damage to Snapping Turtle.
# 💥 Oh no! Snapping Turtle takes 6 damage! (HP: 16/28)
#
# Snapping Turtle's turn...
# 🐢 The turtle slowly opens its jaws...
# ⚠️ CHOMP!!!
# 🎲 Snapping Turtle attacks! Roll: 20 + STR(5) = 25
# ✅ Hit! Snapping Turtle deals 5 damage to Sir Quacks-a-Lot.
# 💥 Oh no! Sir Quacks-a-Lot takes 5 damage! (HP: 22/40)
#
# Sir Quacks-a-Lot (HP: 22/40) | Snapping Turtle (HP: 16/28)
# What do you do? (attack / run)
# 🎲 Sir Quacks-a-Lot attacks! Roll: 10 + STR(6) = 16
# ✅ Hit! Sir Quacks-a-Lot deals 6 damage to Snapping Turtle.
# 💥 Oh no! Snapping Turtle takes 6 damage! (HP: 10/28)
#
# Snapping Turtle's turn...
# 🐢 The turtle slowly opens its jaws...
# ⚠️ CHOMP!!!
# 🎲 Snapping Turtle attacks! Roll: 17 + STR(5) = 22
# ✅ Hit! Snapping Turtle deals 5 damage to Sir Quacks-a-Lot.
# 💥 Oh no! Sir Quacks-a-Lot takes 5 damage! (HP: 17/40)
#
# Sir Quacks-a-Lot (HP: 17/40) | Snapping Turtle (HP: 10/28)
# What do you do? (attack / run)
# 🎲 Sir Quacks-a-Lot attacks! Roll: 18 + STR(6) = 24
# ✅ Hit! Sir Quacks-a-Lot deals 6 damage to Snapping Turtle.
# 💥 Oh no! Snapping Turtle takes 6 damage! (HP: 4/28)
#
# Snapping Turtle's turn...
# 🐢 The turtle slowly opens its jaws...
# ⚠️ CHOMP!!!
# 🎲 Snapping Turtle attacks! Roll: 19 + STR(5) = 24
# ✅ Hit! Snapping Turtle deals 5 damage to Sir Quacks-a-Lot.
# 💥 Oh no! Sir Quacks-a-Lot takes 5 damage! (HP: 12/40)
#
# Sir Quacks-a-Lot (HP: 12/40) | Snapping Turtle (HP: 4/28)
# What do you do? (attack / run)
# 🎲 Sir Quacks-a-Lot attacks! Roll: 1 + STR(6) = 7
# ❌ Miss! Snapping Turtle's DEF(13) blocks the attack.
#
# Snapping Turtle's turn...
# 🐢 The turtle slowly opens its jaws...
# ⚠️ CHOMP!!!
# 🎲 Snapping Turtle attacks! Roll: 5 + STR(5) = 10
# ❌ Miss! Sir Quacks-a-Lot's DEF(12) blocks the attack.
#
# Sir Quacks-a-Lot (HP: 12/40) | Snapping Turtle (HP: 4/28)
# What do you do? (attack / run)
# 🎲 Sir Quacks-a-Lot attacks! Roll: 14 + STR(6) = 20
# ✅ Hit! Sir Quacks-a-Lot deals 6 damage to Snapping Turtle.
# 💥 Oh no! Snapping Turtle takes 6 damage! (HP: 0/28)
#
# 🎉 Snapping Turtle has been defeated!
# ⏳ Time left until Quackie O gets home: 14 turns
# ⏳ Time left until Quackie O gets home: 13 turns
#
# What do you do? (type 'help' for commands)
# Sir Quacks-a-Lot picked up: Shiny Pebble
# ⏳ Time left until Quackie O gets home: 12 turns
#
# What do you do? (type 'help' for commands)
#
# ==================================================
# 📍 Belvedere Castle
# ==================================================
# A mini castle with haunting energy. Echoes bounce off the stone walls.
#
# ✨ You see:
#   - Duckling: Pip
#
# 🚪 Exits: west
# ⏳ Time left until Quackie O gets home: 11 turns
#
# What do you do? (type 'help' for commands)
# Sir Quacks-a-Lot picked up: Duckling: Pip
# 🦆 You found one of your ducklings!!
# ⏳ Time left until Quackie O gets home: 10 turns
#
# What do you do? (type 'help' for commands)
#
# ==================================================
# 📍 The Pond
# ==================================================
# The water is calm… too calm. A turtle is posted up like security.
#
# 🚪 Exits: south, east, west
# ⏳ Time left until Quackie O gets home: 9 turns
#
# What do you do? (type 'help' for commands)
#
# ==================================================
# 📍 Cherry Hill
# ==================================================
# A peaceful hill with benches and trees. You swear you hear faint peeping nearby.
#
# 👀 Threats nearby:
#   - Raccoon (HP 16/16, DEF 11)
#
# 🚪 Exits: east, north
#
# ⚠️ An enemy is here!
#
# ⚔️ COMBAT BEGINS! ⚔️
# Sir Quacks-a-Lot vs Raccoon!
#
# Sir Quacks-a-Lot (HP: 12/40) | Raccoon (HP: 16/16)
# What do you do? (attack / run)
# 🎲 Sir Quacks-a-Lot attacks! Roll: 13 + STR(6) = 19
# ✅ Hit! Sir Quacks-a-Lot deals 6 damage to Raccoon.
# 💥 Oh no! Raccoon takes 6 damage! (HP: 10/16)
#
# Raccoon's turn...
# 🦝 The raccoon hisses and lunges from the shadows!
# 🗑️ It swings a mysterious trash item at you!
# 🎲 Raccoon attacks! Roll: 14 + STR(3) = 17
# ✅ Hit! Raccoon deals 3 damage to Sir Quacks-a-Lot.
# 💥 Oh no! Sir Quacks-a-Lot takes 3 damage! (HP: 9/40)
#
# Sir Quacks-a-Lot (HP: 9/40) | Raccoon (HP: 10/16)
# What do you do? (attack / run)
# 🎲 Sir Quacks-a-Lot attacks! Roll: 14 + STR(6) = 20
# ✅ Hit! Sir Quacks-a-Lot deals 6 damage to Raccoon.
# 💥 Oh no! Raccoon takes 6 damage! (HP: 4/16)
#
# Raccoon's turn...
# 🦝 The raccoon hisses and lunges from the shadows!
# 🗑️ It swings a mysterious trash item at you!
# 🎲 Raccoon attacks! Roll: 14 + STR(3) = 17
# ✅ Hit! Raccoon deals 3 damage to Sir Quacks-a-Lot.
# 💥 Oh no! Sir Quacks-a-Lot takes 3 damage! (HP: 6/40)
#
# Sir Quacks-a-Lot (HP: 6/40) | Raccoon (HP: 4/16)
# What do you do? (attack / run)
# 🎲 Sir Quacks-a-Lot attacks! Roll: 18 + STR(6) = 24
# ✅ Hit! Sir Quacks-a-Lot deals 6 damage to Raccoon.
# 💥 Oh no! Raccoon takes 6 damage! (HP: 0/16)
#
# 🎉 Raccoon has been defeated!
# ⏳ Time left until Quackie O gets home: 8 turns
# ⏳ Time left until Quackie O gets home: 7 turns
#
# What do you do? (type 'help' for commands)
#
# 📜 AVAILABLE COMMANDS:
#   go [direction] - Move (north, south, east, west)
#   look          - Examine your surroundings
#   take [item]   - Pick up an item (try: take pip)
#   fight         - Start combat if an enemy is here
#   inventory     - Check your inventory
#   help          - Show this help message
#   quit          - Exit the game
#   use [item]    - Use an item from your inventory (try: use band-aid)
#   talk [person] - Talk to someone nearby (try: talk old man)
#
# What do you do? (type 'help' for commands)
# Inventory:
#   1. Bread Crumbs
#   2. Band-Aid
#   3. Duckling: Sip
#   4. Shiny Pebble
#   5. Duckling: Pip
#
# What do you do? (type 'help' for commands)
# You don't have that item.
#
# What do you do? (type 'help' for commands)
# 💚 Sir Quacks-a-Lot heals 6 HP! (HP: 12/40)
# ✅ Used: Band-Aid
# ⏳ Time left until Quackie O gets home: 6 turns
#
# What do you do? (type 'help' for commands)
#
# ==================================================
# 📍 The Pond
# ==================================================
# The water is calm… too calm. A turtle is posted up like security.
#
# 🚪 Exits: south, east, west
# ⏳ Time left until Quackie O gets home: 5 turns
#
# What do you do? (type 'help' for commands)
#
# ==================================================
# 📍 Cherry Hill
# ==================================================
# A peaceful hill with benches and trees. You swear you hear faint peeping nearby.
#
# 🚪 Exits: east, north
# ⏳ Time left until Quackie O gets home: 4 turns
#
# What do you do? (type 'help' for commands)
#
# ==================================================
# 📍 Strawberry Fields
# ==================================================
# Quiet and calm. A place where you can think… but don’t think too long.
#
# ✨ You see:
#   - Duckling: Mip
#
# 🚪 Exits: south
# ⏳ Time left until Quackie O gets home: 3 turns
#
# What do you do? (type 'help' for commands)
# Sir Quacks-a-Lot picked up: Duckling: Mip
# 🦆 You found one of your ducklings!!
#
# ============================================================
#                     🎉 VICTORY! 🎉
# ============================================================
#
# Pip, Mip, and Sip are safe and accounted for.
# Quackie O returns relaxed… and proud.
# 🦆 Family reunited. Parenting: SUCCESS.

# %% [markdown]
# ---
#
# ## Part 7: Polish & Creativity
#
# Use your out-of-class time to make your game awesome!
#
# ### Ideas for Enhancement:
#
# **More Interesting Combat:**
# - Add special abilities (power attack, healing, magic)
# - Implement critical hits (roll a 20!)
# - Add combat items (potions, bombs)
#
# **Better World Building:**
# - Add more locations with interesting descriptions
# - Include environmental storytelling
# - Add NPCs who give hints or quests
#
# **Items & Inventory:**
# - Weapons that increase damage
# - Armor that increases defense
# - Keys that unlock doors
# - Potions that restore health
#
# **Personality & Style:**
# - Fun enemy names and descriptions
# - Witty combat messages
# - ASCII art for dramatic moments
# - Sound effects (print "*CLANG*" or "*WHOOSH*")
#
# ### ASCII Art Examples:
#
# ```
#    _____                       ____
#   / ____|                     / __ \
#  | |  __  __ _ _ __ ___   ___| |  | |_   _____ _ __
#  | | |_ |/ _` | '_ ` _ \ / _ \ |  | \ \ / / _ \ '__|
#  | |__| | (_| | | | | | |  __/ |__| |\ V /  __/ |
#   \_____|\__,_|_| |_| |_|\___|\____/  \_/ \___|_|
#
#
#      /\_/\
#     ( o.o )
#      > ^ <    A wild monster appears!
#     /|   |\
#    (_|   |_)
# ```

# %% [markdown]
# ---
#
# ## Deliverables Checklist ✅
#
# Before submitting, make sure you have created a `labs/LAB01_submission/` folder containing the following:
#
# ### Required:
# - [ ] **`game.py`** (and other `.py` files if you prefer) — working game with minimum 5 classes, proper inheritance, 4-6 connected locations, dice-based combat, and win/lose conditions
# - [ ] **`design.md`** — your game design document (theme, goals, class hierarchy, map, etc.)
# - [ ] **`readme.md`** — instructions explaining how to play your game
# - [ ] **`reflection.md`** — 2-3 paragraphs reflecting on your OOP design decisions
#
# ### Testing Checklist (before copying to `.py`):
# - [ ] Can create and customize player character
# - [ ] Can move between locations
# - [ ] Combat system works with dice rolls
# - [ ] Can win the game
# - [ ] Can lose the game (death)
# - [ ] No crashes on invalid input
#
# ### Stretch Goals (Optional):
# - [ ] Item system (weapons, armor, potions)
# - [ ] Multiple enemy types with unique behaviors
# - [ ] Special abilities or magic system
# - [ ] Save/load game to file
# - [ ] Leveling system with XP

# %% [markdown]
# ---
#
# ## README: How to Play Your Game
#
# *Write instructions for someone who has never seen your game. What's the story? What commands can they use? What's the goal?*
#
# > **Submission note**: Use this cell as a workspace to draft your README, then copy the final version to `labs/LAB01_submission/readme.md`.
#
# ### Game Title: Sir Quacks-a-Lot: Central Park Rescue (Dad Mode Activated)
#
# ### Story:
# You play as Sir Quacks-a-Lot, a proud father duck who was left in charge of watching his three ducklings while his wife, Quackie O, takes a well-deserved vacation. Everything was going fine… until you looked away for literally one second and Pip, Mip, and Sip disappeared somewhere in Central Park.
# Now Sir Quacks-a-Lot has to explore the park, deal with chaotic enemies like raccoons, off-leash dogs, and overly excited kids, and search different locations to find his ducklings before Quackie O gets home.
# No pressure… but if she comes back and the ducklings are still missing, you’re in serious trouble.
#
# ### How to Play:
# You control Sir Quacks-a-Lot by typing commands in the terminal. Here are the main ones:
# go [direction] → Move somewhere (north, south, east, west)
# look → Re-describe the current location
# fight or attack → Fight an enemy in the area
# take [item] → Pick up an item you see
# use [item] → Use an item from your inventory
# talk [person] → Talk to someone nearby (like the old man in the park)
# inventory or i → Check what you're carrying
# help → Show the list of commands
# quit → Exit the game
# During combat, you’ll be asked to type:
# attack → Attack the enemy
# run → Try to escape (50% chance)
#
# ### Goal:
# Your goal is to find all three missing ducklings (Pip, Mip, and Sip) somewhere around Central Park before the timer runs out and Quackie O comes home.
# If you collect all three ducklings in your inventory, you win the game.
# If you run out of turns or Sir Quacks-a-Lot gets defeated in combat, the game ends.
#
# ### Tips:
# Explore every location carefully — the ducklings could be anywhere.
# Some enemies are stronger than others, so sometimes it’s smarter to run.
# Pick up items you find because some of them can heal you or boost your strength.
# If you see the Old Man in the park, talk to him — he might give you something helpful.
# Keep an eye on the timer (number of rounds left)… Quackie O is coming home soon.

# %% [markdown]
# ---
#
# ## Reflection: OOP Design Decisions
#
# *Write 2-3 paragraphs reflecting on your object-oriented design. Some questions to consider:*
#
# - *Why did you structure your classes the way you did?*
# - *What inheritance relationships did you use and why?*
# - *What was challenging about managing multiple interacting objects?*
# - *If you had more time, what would you refactor or add?*
# - *How does this experience connect to working with OOP in analytics/ML codebases?*
#
# > **Submission note**: Use this cell as a workspace to draft your reflection, then copy the final version to `labs/LAB01_submission/reflection.md`.
#
# ---
#
# I structured the game around a few core classes because it made the whole project way easier to reason about and expand. I used Character as the base for anything that can fight (health, strength, defense, attack logic), then built Player and Enemy on top of that so they share the same combat “rules” without me rewriting code twice. That inheritance setup felt clean because the player and enemies are basically the same type of object in combat, the only real difference is the player has extra stuff like an inventory and item interactions. I also kept the world separate with a Location class so each area in the park could store its own description, exits, items, and enemies without the Game class turning into one giant messy blob.
# The hardest part was honestly just keeping track of how everything interacts at once: locations contain enemies and items, the player moves between locations, combat temporarily takes over the input loop, and the game state has to switch correctly between exploring, combat, victory, and game over. Little logic issues show up fast (like trying to fight a defeated enemy, or forgetting to update the turn timer after certain actions), so it forced me to be consistent about where state updates happen. If i had more time I would add more NPC interactions (like the old man) and maybe a simple quest log so it feels more like an actual “mission” rather than just collecting things.
# This connects a lot to OOP in analytics/ML codebases because the same design patterns show up all the time: you’ll have a base model class and then subclasses for different algorithms, shared utilities for preprocessing, and separate objects for data loading, evaluation, and metrics. The biggest similarity is that when multiple objects depend on each other (data objects, model objects, config objects, pipelines), things can get confusing fast unless you keep responsibilities clean and predictable. Building the game made it obvious why good class boundaries matter, it’s the difference between being able to add features quickly vs. breaking everything every time you change one thing (which happened an embarasing amount of times).
#
# ---

# %% [markdown]
# ---
#
# ## Final Tips for Success 🎯
#
# 1. **Build iteratively**: Get the simplest version working first, then add features.
#
# 2. **Test constantly**: After each change, run your code to catch bugs early.
#
# 3. **Use print statements**: When debugging, add `print()` statements to see what's happening.
#
# 4. **Keep methods small**: Each method should do ONE thing. If it's getting long, break it up.
#
# 5. **Have fun**: This is YOUR game. Make it something you enjoy building!
#
# ---
#
# *"Roads? Where we're going, we don't need roads."* — Doc Brown
#
# Good luck, adventurer! 🚀
